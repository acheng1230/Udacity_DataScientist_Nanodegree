# %%
import numpy as np
import pandas as pd
from nbapy import league
pd.set_option('max_columns', None)

# %%
stats = league.PlayerStats(season='2018-2019').stats()
stats
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-33de696ef257> in <module>
# ----> 1 stats = league.PlayerStats(season='2018-2019').stats()
#       2 stats
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nbapy/league.py in __init__(self, season_type, measure_type, per_mode, plus_minus, pace_adjust, rank, season, playoff_round, outcome, location, month, season_segment, date_from, date_to, opponent_team_id, vs_conference, vs_division, team_id, conference, division, game_segment, period, shot_clock_range, last_n_games, game_scope, player_experience, player_position, starter_bench, draft_year, draft_pick, college, country, height, weight)
#     213             "Weight": weight,
#     214         }
# --> 215         self.api = NbaAPI(self._endpoint, self._params)
#     216
#     217     def stats(self):
#
# ...

# %%
league.PlayerTrackingStats(season='2019-20').stats()
# Out:
#      PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0       203932       Aaron Gordon  1610612753               ORL  62  30  32
# 1      1628988      Aaron Holiday  1610612754               IND  66  42  24
# 2      1627846        Abdel Nader  1610612760               OKC  55  37  18
# 3      1629690        Adam Mokoka  1610612741               CHI  11   3   8
# 4      1629678  Admiral Schofield  1610612764               WAS  33   9  24
# ..         ...                ...         ...               ...  ..  ..  ..
# 524     203897        Zach LaVine  1610612741               CHI  60  20  40
# 525    1629668   Zach Norvell Jr.  1610612744               GSW   5   2   3
# 526    1629015       Zhaire Smith  1610612755               PHI   7   3   4
# 527    1629627    Zion Williamson  1610612740               NOP  24  11  13
# 528    1629597     Zylan Cheatham  1610612740               NOP   4   2   2
#
# ...
